# %% [markdown]
# https://bayesball.github.io/BOOK/bayesian-hierarchical-modeling.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymc as pm
import arviz as az
import seaborn as sns

# %%
print(f"Running on PyMC v{pm.__version__}")
# Out:
# Running on PyMC v5.9.2

# %%
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)

# %config InlineBackend.figure_format = 'retina'
az.style.use("arviz-darkgrid")

# %%
df_raw = pd.read_csv('Data/2010_animation_ratings.csv')
df_raw.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0     177    78637     2.5  1435837464
# 1     514    76093     4.0  1533872585
# 2     252    78499     5.0  1498284330
# 3     567    76093     2.5  1525287804
# 4     586    81847     4.5  1529903135
#
#                                                title  Group_Number
# 0  Shrek Forever After (a.k.a. Shrek: The Final C...             3
# 1                    How to Train Your Dragon (2010)             1
# 2                                 Toy Story 3 (2010)             2
# 3                    How to Train Your Dragon (2010)             1
# 4                                     Tangled (2010)             8

# %%
df = df_raw.drop(columns=['userId', 'movieId', 'timestamp'])
df.head()
# Out:
#    rating                                              title  Group_Number
# 0     2.5  Shrek Forever After (a.k.a. Shrek: The Final C...             3
# 1     4.0                    How to Train Your Dragon (2010)             1
# 2     5.0                                 Toy Story 3 (2010)             2
# 3     2.5                    How to Train Your Dragon (2010)             1
# 4     4.5                                     Tangled (2010)             8

# %%
df.nunique()
# Out:
# rating          7
# title           8
# Group_Number    8
# dtype: int64

# %%
# List of full movie titles
titles = df['title'].unique()
title_to_ratings = {title: df[df['title'] == title]['rating'].values for title in titles}

# Manually create a dictionary mapping full titles to short titles
title_to_short = {
    'Shrek Forever After (a.k.a. Shrek: The Final Chapter) (2010)': 'Shrek',
    'How to Train Your Dragon (2010)': 'Dragon',
    'Toy Story 3 (2010)': 'Toy Story',
    'Tangled (2010)': 'Tangled',
    'Despicable Me (2010)': 'Despicable me',
    'Legend of the Guardians: The Owls of Ga\'Hoole (2010)': 'Guardians',
    'Megamind (2010)': 'Megamind',
    'Batman: Under the Red Hood (2010)': 'Batman'
}

# %%
# Create a new column 'short_title' by mapping the 'title' column through the dictionary
df['short_title'] = df['title'].map(title_to_short)

# Display the DataFrame to verify the new column
df.head()
# Out:
#    rating                                              title  Group_Number  \
# 0     2.5  Shrek Forever After (a.k.a. Shrek: The Final C...             3
# 1     4.0                    How to Train Your Dragon (2010)             1
# 2     5.0                                 Toy Story 3 (2010)             2
# 3     2.5                    How to Train Your Dragon (2010)             1
# 4     4.5                                     Tangled (2010)             8
#
#   short_title
# 0       Shrek
# 1      Dragon
# 2   Toy Story
# 3      Dragon
# 4     Tangled

# %%
# Create a numeric category for movie titles
df['title_cat'] = pd.Categorical(df['short_title']).codes

# Generating jitter for the x-axis
x_jitter = 0.2 * np.random.rand(len(df))  # Adjust 0.1 to increase or decrease the jitter
y_jitter = 0.2 * np.random.rand(len(df))  # Jitter for y-axis, similar scale as x-axis

# Set up the plot
plt.figure(figsize=(8, 6))

# Creating the scatter plot
plt.scatter(df['rating'] + x_jitter, df['title_cat'] + y_jitter, alpha=0.5)

# Setting the x-axis to show movie titles instead of numbers
plt.yticks(df['title_cat'].unique(), df['short_title'].unique(), rotation=0)

plt.title('Scatter Plot of Movie Ratings')
plt.ylabel('Movie Title')
plt.xlabel('Rating')

# Show the plot
plt.tight_layout()  # Adjust layout to make sure labels are readable
plt.show()
# Out:
# /var/folders/3v/qbgbs1s16ds_0dymg_tpg8040000gn/T/ipykernel_8961/3693463449.py:22: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()  # Adjust layout to make sure labels are readable

# %%
# Group by 'title' and aggregate the data
summary_df = df.groupby('title')['rating'].agg(['mean', 'std', 'count'])

# %%
summary_df
# Out:
#                                                         mean       std  count
# title
# Batman: Under the Red Hood (2010)                   5.000000       NaN      1
# Despicable Me (2010)                                3.722222  0.618017      9
# How to Train Your Dragon (2010)                     3.409091  0.860761     11
# Legend of the Guardians: The Owls of Ga'Hoole (...  4.000000       NaN      1
# Megamind (2010)                                     3.375000  1.314978      4
# Shrek Forever After (a.k.a. Shrek: The Final Ch...  4.000000  1.322876      3
# Tangled (2010)                                      4.200000  0.888194     10
# Toy Story 3 (2010)                                  3.812500  0.963933     16

# %% [markdown]
# ## Build the Normal Hierarchical Model

# %%
from pymc import Model, Normal, Gamma, Deterministic, sample, HalfNormal, InverseGamma

with Model() as simple_normal_model:
    # Define Stage 2 priors - Hyperprior
    mu = Normal("mu", mu=3, sigma=1)
    sigma = InverseGamma('sigma', alpha=1, beta=1)

    # Define Stage 1 priors
    mu_i = Normal("mu_i", mu=mu, sigma=sigma, shape=len(titles))
    sigma_common =  InverseGamma('sigma_common', alpha=1, beta=1)

    # Define likelihood
    obs = {}
    for i, title in enumerate(titles):
        obs[title] = Normal(f'obs_{title}', mu=mu_i[i], sigma=sigma_common, observed=title_to_ratings[title])

    # Inference!
    trace = sample(3000, return_inferencedata=True, tune=1000, target_accept=0.9)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma, mu_i, sigma_common]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='16000' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16000/16000 00:04&lt;00:00 Sampling 4 chains, 3 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 3_000 draw iterations (4_000 + 12_000 draws total) took 4 seconds.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
with simple_normal_model:
    prior_check = pm.sample_prior_predictive(samples=1000, var_names=['mu', 'sigma', 'mu_i', 'sigma_common'])
# Out:
# Sampling: [mu, mu_i, sigma, sigma_common]

# %%
mu_samples = prior_check.prior['mu'].values.flatten()
sigma_samples = prior_check.prior['sigma'].values.flatten()

# %%
# Plotting histograms
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)  # First subplot for 'mu'
sns.histplot(mu_samples, bins=30, kde=True, color='blue', alpha=0.7)
plt.title('Prior Predictive Distribution of mu')
plt.xlabel('mu values')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)  # Second subplot for 'sigma'
sns.histplot(sigma_samples, bins=1000, kde=True, color='green', alpha=0.7)
plt.title('Prior Predictive Distribution of sigma')
plt.xlabel('sigma values')
plt.xlim(0,100)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/3v/qbgbs1s16ds_0dymg_tpg8040000gn/T/ipykernel_8961/297144764.py:16: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# Check the trace summary for results
summary = pm.summary(trace)
summary
# Out:
#                mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# mu            3.784  0.211   3.386    4.186      0.002    0.002    7969.0
# mu_i[0]       3.863  0.349   3.210    4.519      0.003    0.002   11113.0
# mu_i[1]       3.549  0.247   3.079    4.004      0.003    0.002    8396.0
# mu_i[2]       3.804  0.201   3.424    4.179      0.002    0.001   11089.0
# mu_i[3]       4.042  0.252   3.574    4.517      0.003    0.002    8495.0
# mu_i[4]       3.749  0.249   3.264    4.216      0.002    0.002   12080.0
# mu_i[5]       3.824  0.416   3.051    4.646      0.004    0.003   11393.0
# mu_i[6]       3.613  0.331   2.979    4.206      0.003    0.002    9923.0
# mu_i[7]       3.992  0.436   3.208    4.862      0.005    0.003    8972.0
# sigma         0.415  0.188   0.140    0.765      0.003    0.002    3642.0
# sigma_common  0.923  0.093   0.752    1.096      0.001    0.001    9683.0
#
#               ess_tail  r_hat
# mu              8434.0    1.0
# mu_i[0]         8180.0    1.0
# mu_i[1]         7844.0    1.0
# mu_i[2]         8328.0    1.0
# mu_i[3]         8607.0    1.0
# mu_i[4]         8778.0    1.0
# mu_i[5]         7771.0    1.0
# mu_i[6]         7060.0    1.0
# mu_i[7]         7186.0    1.0
# sigma           4910.0    1.0
# sigma_common    8092.0    1.0

# %%
az.plot_energy(trace);

# %%
az.plot_trace(trace, var_names=['mu', 'sigma', 'mu_i', 'sigma_common'], figsize=(10, 7));

# %%
pm.model_to_graphviz(simple_normal_model)

# %%
pm.model_to_graphviz?
# Out:
# Signature:
# pm.model_to_graphviz(
#     model=None,
#     *,
#     var_names: Optional[Iterable[pymc.util.VarName]] = None,
#     formatting: str = 'plain',
# )
# Docstring:
# Produce a graphviz Digraph from a PyMC model.
#
# Requires graphviz, which may be installed most easily with
#     conda install -c conda-forge python-graphviz
#
# Alternatively, you may install the `graphviz` binaries yourself,
# and then `pip install graphviz` to get the python bindings.  See
# http://graphviz.readthedocs.io/en/stable/manual.html
# for more information.
#
# Parameters
# ----------
# model : pm.Model
#     The model to plot. Not required when called from inside a modelcontext.
# var_names : iterable of variable names, optional
#     Subset of variables to be plotted that identify a subgraph with respect to the entire model graph
# formatting : str, optional
#     one of { "plain" }
#
# Examples
# --------
# How to plot the graph of the model.
#
# .. code-block:: python
#
#     import numpy as np
#     from pymc import HalfCauchy, Model, Normal, model_to_graphviz
#
#     J = 8
#     y = np.array([28, 8, -3, 7, -1, 1, 18, 12])
#     sigma = np.array([15, 10, 16, 11, 9, 11, 10, 18])
#
#     with Model() as schools:
#
#         eta = Normal("eta", 0, 1, shape=J)
#         mu = Normal("mu", 0, sigma=1e6)
#         tau = HalfCauchy("tau", 25)
#
#         theta = mu + tau * eta
#
#         obs = Normal("obs", theta, sigma=sigma, observed=y)
#
#     model_to_graphviz(schools)
# File:      ~/miniforge3/envs/pymc_env/lib/python3.11/site-packages/pymc/model_graph.py
# Type:      function
